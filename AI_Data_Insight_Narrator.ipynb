# %%
# !pip install openai pandas

# %%
import os
import pandas as pd

# Optional: only if using OpenAI
try:
    from openai import OpenAI
except:
    pass

# %%
# Create sample dataset
data = {
    "Quarter": ["Q1", "Q2", "Q3", "Q4"],
    "Category": ["Electronics", "Clothing", "Electronics", "Furniture"],
    "Sales": [12000, 9000, 15000, 8000]
}

df = pd.DataFrame(data)
df.to_csv("sales_data_sample.csv", index=False)
df.head()
# Out:
#   Quarter     Category  Sales
# 0      Q1  Electronics  12000
# 1      Q2     Clothing   9000
# 2      Q3  Electronics  15000
# 3      Q4    Furniture   8000

# %%
def generate_insights(df, use_openai=False):
    data_sample = df.head(20).to_string()

    if use_openai:
        prompt = f"""
        You are a data analyst. Here is a dataset sample:

        {data_sample}

        Please analyze it and provide clear, simple insights in plain English.
        """
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": "You are a helpful AI that explains data in plain English."},
                {"role": "user", "content": prompt}
            ]
        )
        return response.choices[0].message.content
    else:
        # Simulated AI output for testing without hitting API
        return """
        Sales peaked in Q3 with Electronics reaching 15,000, a 25% increase from Q1.
        Clothing performed moderately in Q2 at 9,000, while Furniture had the lowest sales in Q4 at 8,000.
        Overall, Electronics was the strongest category.
        """

# %%
insights = generate_insights(df, use_openai=False)  # Set True if you have API quota
print(" AI Insights:\n")
print(insights)
# Out:
#  AI Insights:
#
#
#         Sales peaked in Q3 with Electronics reaching 15,000, a 25% increase from Q1.
#         Clothing performed moderately in Q2 at 9,000, while Furniture had the lowest sales in Q4 at 8,000.
#         Overall, Electronics was the strongest category.

# %%
with open("insights.txt", "w") as f:
    f.write(insights)
